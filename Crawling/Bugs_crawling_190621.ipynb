# %%
import pandas as pd
import numpy as np
import re

import requests
from bs4 import BeautifulSoup

from selenium import webdriver as wd
import time

import pickle

from selenium.common.exceptions import NoSuchElementException

# %%
path = "C:/Users/wldnf/Downloads/chromedriver_win32/chromedriver.exe" #자신의 chromedriver 위치 할당

# %% [markdown]
# ## Final

# %% [markdown]
# 1. 연도별 링크 뽑기

# %%
driver = wd.Chrome(path)
url = 'https://music.bugs.co.kr/years'
driver.get(url)

# %%
# 성인인증이 필요한 노래 가사를 위하여 로그인
driver.find_element_by_id('loginHeader').find_element_by_tag_name('a').click()
driver.find_element_by_id('to_bugs_login').click()
driver.find_element_by_name('user_id').send_keys('') # 벅스 아이디 입력
driver.find_element_by_name('passwd').send_keys('') # 벅스 비밀번호 입력
driver.find_element_by_class_name('submit').click()

# %%
# 연도별 접근 링크 뽑기
year_link_list = []

infos = driver.find_elements_by_class_name("info")
for info in infos:
    link = info.find_element_by_tag_name("a").get_attribute('href')
    year_link_list.append(link)
year_link_list
# Out:
# ['https://music.bugs.co.kr/musicpd/albumview/30871',
#  'https://music.bugs.co.kr/musicpd/albumview/25698',
#  'https://music.bugs.co.kr/musicpd/albumview/20440',
#  'https://music.bugs.co.kr/musicpd/albumview/15389',
#  'https://music.bugs.co.kr/musicpd/albumview/11152',
#  'https://music.bugs.co.kr/musicpd/albumview/7479',
#  'https://music.bugs.co.kr/musicpd/albumview/6683',
#  'https://music.bugs.co.kr/musicpd/albumview/6684',
#  'https://music.bugs.co.kr/musicpd/albumview/6685',
#  'https://music.bugs.co.kr/musicpd/albumview/6709',
#  'https://music.bugs.co.kr/musicpd/albumview/6710',
#  'https://music.bugs.co.kr/musicpd/albumview/6712',
#  'https://music.bugs.co.kr/musicpd/albumview/6713',
#  'https://music.bugs.co.kr/musicpd/albumview/6715',
#  'https://music.bugs.co.kr/musicpd/albumview/6716',
#  'https://music.bugs.co.kr/musicpd/albumview/6717',
#  'https://music.bugs.co.kr/musicpd/albumview/6718',
#  'https://music.bugs.co.kr/musicpd/albumview/6719',
#  'https://music.bugs.co.kr/musicpd/albumview/6720',
#  'https://music.bugs.co.kr/musicpd/albumview/6708',
#  'https://music.bugs.co.kr/musicpd/albumview/6790',
#  'https://music.bugs.co.kr/musicpd/albumview/6791',
#  'https://music.bugs.co.kr/musicpd/albumview/6792',
#  'https://music.bugs.co.kr/musicpd/albumview/6793',
#  'https://music.bugs.co.kr/musicpd/albumview/6794',
#  'https://music.bugs.co.kr/musicpd/albumview/6795',
#  'https://music.bugs.co.kr/musicpd/albumview/6796',
#  'https://music.bugs.co.kr/musicpd/albumview/6798',
#  'https://music.bugs.co.kr/musicpd/albumview/6799',
#  'https://music.bugs.co.kr/musicpd/albumview/6800',
#  'https://music.bugs.co.kr/musicpd/albumview/6788',
#  'https://music.bugs.co.kr/musicpd/albumview/6835',
#  'https://music.bugs.co.kr/musicpd/albumview/6834',
#  'https://music.bugs.co.kr/musicpd/albumview/6833',
#  'https://music.bugs.co.kr/musicpd/albumview/6832',
#  'https://music.bugs.co.kr/musicpd/albumview/6831',
#  'https://music.bugs.co.kr/musicpd/albumview/6830',
#  'https://music.bugs.co.kr/musicpd/albumview/6829',
#  'https://music.bugs.co.kr/musicpd/albumview/6828',
#  'https://music.bugs.co.kr/musicpd/albumview/6827',
#  'https://music.bugs.co.kr/musicpd/albumview/6826',
#  'https://music.bugs.co.kr/musicpd/albumview/6825',
#  'https://music.bugs.co.kr/musicpd/albumview/6824',
#  'https://music.bugs.co.kr/musicpd/albumview/6823',
#  'https://music.bugs.co.kr/musicpd/albumview/6822',
#  'https://music.bugs.co.kr/musicpd/albumview/6821',
#  'https://music.bugs.co.kr/musicpd/albumview/6820',
#  'https://music.bugs.co.kr/musicpd/albumview/6819',
#  'https://music.bugs.co.kr/musicpd/albumview/6818',
#  'https://music.bugs.co.kr/musicpd/albumview/6817',
#  'https://music.bugs.co.kr/musicpd/albumview/6816',
#  'https://music.bugs.co.kr/musicpd/albumview/6815',
#  'https://music.bugs.co.kr/musicpd/albumview/6814',
#  'https://music.bugs.co.kr/musicpd/albumview/6813',
#  'https://music.bugs.co.kr/musicpd/albumview/6812',
#  'https://music.bugs.co.kr/musicpd/albumview/6811',
#  'https://music.bugs.co.kr/musicpd/albumview/6810',
#  'https://music.bugs.co.kr/musicpd/albumview/6809',
#  'https://music.bugs.co.kr/musicpd/albumview/6808',
#  'https://music.bugs.co.kr/musicpd/albumview/6804',
#  'https://music.bugs.co.kr/musicpd/albumview/6803',
#  'https://music.bugs.co.kr/musicpd/albumview/6802',
#  'https://music.bugs.co.kr/musicpd/albumview/6801']

# %% [markdown]
# 2. 연도별 링크에서 곡별 정보 뽑기

# %%
year_list = []
title_list = []
singer_list = []
time_list = []
lyric_list = []
singer_type_list = []

# %%
for year_link in year_link_list:
    # 연도별 TOP100 페이지로 이동
    driver.get(year_link)
    time.sleep(2)
    
    # 연도
    year = driver.find_element_by_id('hyrendContentBody').find_element_by_tag_name('h1').text
    # 연도별 곡 개수
    innercontainer4_tbody = driver.find_elements_by_class_name('innerContainer')[3].find_element_by_tag_name('tbody')
    innercontainer4_trs = innercontainer4_tbody.find_elements_by_tag_name('tr')
    year_song_num = len(innercontainer4_trs)
    for i in range(year_song_num):
        year_list.append(year)
    
    # 해당 연도의 TOP100 곡별 링크 뽑기
    song_url_list = []
    song_trackinfo = innercontainer4_tbody.find_elements_by_class_name('trackInfo')
    for trackinfo in song_trackinfo:
        song_url_list.append(trackinfo.get_attribute('href'))
    
    # 곡별 링크에서 관련 정보 뽑기
    for song_url in song_url_list:
        driver.get(song_url)
        time.sleep(2)
    
        # 타이틀
        title = driver.find_element_by_id('hyrendContentBody').find_element_by_tag_name('h1').text
        title_list.append(title)
    
        # 가사
        try:
            lyric = driver.find_element_by_class_name('lyricsContainer').find_element_by_tag_name('xmp').text
            lyric_list.append(lyric)
        except NoSuchElementException:
            lyric = 'NA'
            lyric_list.append(lyric)
    
        # 가수
        song_info = driver.find_element_by_class_name('info')
        singer = song_info.find_element_by_tag_name('td').text
        singer_list.append(singer)
    
        # 시간
        runtime = song_info.find_element_by_tag_name('time').text
        time_list.append(runtime)
    
        # 솔로/그룹(성별)
        type_url = song_info.find_element_by_tag_name('td').find_element_by_tag_name('a').get_attribute('href')
        driver.get(type_url)
        time.sleep(2)
    
        singer_type = driver.find_element_by_class_name('info').find_element_by_tag_name('td').text
        singer_type_list.append(singer_type)

# %%
print(len(title_list),len(year_list),len(singer_list),len(time_list),len(singer_type_list),len(lyric_list))
# Out:
# 5146 5146 5146 5146 5146 5146

# %%
from collections import Counter

Counter(singer_type_list) # 그룹유형이 대한민국/미국으로 크롤링된 경우가 있음
# Out:
# Counter({'그룹 (남성)': 703,
#          '듀오 (남성)': 281,
#          '솔로 (남성)': 2100,
#          '그룹 (여성)': 318,
#          '솔로 (여성)': 1394,
#          '듀오 (여성)': 83,
#          '그룹 (혼성)': 162,
#          '듀오 (혼성)': 51,
#          '그룹': 5,
#          '솔로': 15,
#          '대한민국': 32,
#          '미국': 2})

# %% [markdown]
# 추가) 앨범별 장르 뽑기

# %%
driver = wd.Chrome(path)
url = 'https://music.bugs.co.kr/years'
driver.get(url)

# %%
genre_list = []

# %%
for year_link in year_link_list:
    # 연도별 TOP100 페이지로 이동
    driver.get(year_link)
    time.sleep(1)
    
    
    # 해당 연도의 TOP100 곡별 링크 뽑기
    song_url_list = []
    innercontainer4_tbody = driver.find_elements_by_class_name('innerContainer')[3].find_element_by_tag_name('tbody')
    song_trackinfo = innercontainer4_tbody.find_elements_by_class_name('trackInfo')
    for trackinfo in song_trackinfo:
        song_url_list.append(trackinfo.get_attribute('href'))
    
    # 곡별 링크에서 관련 정보 뽑기
    for song_url in song_url_list:
        driver.get(song_url)
        time.sleep(1)
        # 장르
        song_info = driver.find_element_by_class_name('info')
        song_info_trs = song_info.find_elements_by_tag_name('tr')

        for tr in song_info_trs:
            if tr.find_element_by_tag_name('th').text=='앨범':
                album_tr = tr
            else:
                pass
    
        album_url = album_tr.find_element_by_tag_name('td').find_element_by_tag_name('a').get_attribute('href')
        driver.get(album_url)
        time.sleep(1)

        album_info = driver.find_element_by_class_name('info')
        album_info_trs = album_info.find_elements_by_tag_name('tr')

        for tr in album_info_trs:
            if tr.find_element_by_tag_name('th').text=='장르':
                genre = tr.find_element_by_tag_name('td').text
                genre_list.append(genre)
            else:
                pass

# %%
len(genre_list)
# Out:
# 5146

# %% [markdown]
# ## 각 정보 pickle 파일로 저장

# %%
## Save pickle
# year
with open("year.pickle","wb") as fw:
    pickle.dump(year_list, fw)
# title
with open("title.pickle","wb") as fw:
    pickle.dump(title_list, fw)
# singer 
with open("singer.pickle","wb") as fw:
    pickle.dump(singer_list, fw)
# runtime
with open("runtime.pickle","wb") as fw:
    pickle.dump(time_list, fw) 
# type    
with open("type.pickle","wb") as fw:
    pickle.dump(singer_type_list, fw)
# lyric
with open("lyric.pickle","wb") as fw:
    pickle.dump(lyric_list, fw)
# genre
with open("genre.pickle","wb") as fw:
    pickle.dump(genre_list, fw)

# %% [markdown]
# ## 각 정보 pickle 파일로 불러오기

# %%
## Load pickle
# year
with open("year.pickle","rb") as fr:
    year_list = pickle.load(fr)

# title
with open("title.pickle","rb") as fr:
    title_list = pickle.load(fr)

# singer
with open("singer.pickle","rb") as fr:
    singer_list = pickle.load(fr)

# runtime
with open("runtime.pickle","rb") as fr:
    time_list = pickle.load(fr)

# type
with open("type.pickle","rb") as fr:
    singer_type_list = pickle.load(fr)

# singer
with open("lyric.pickle","rb") as fr:
    lyric_list = pickle.load(fr)

# genre
with open("genre.pickle","rb") as fr:
    genre_list = pickle.load(fr)

# %% [markdown]
# ## 데이터프레임 만들기

# %%
bugs_df = pd.DataFrame({'year':year_list,'title':title_list, 'singer':singer_list, 'genre':genre_list,
                        'runtime':time_list, 'type':singer_type_list,'lyric':lyric_list})
bugs_df
# Out:
#                       year                                  title  \
# 0         2018년 베스트 가요 콜렉션                 사랑을 했다 (LOVE SCENARIO)
# 1         2018년 베스트 가요 콜렉션                                   그날처럼
# 2         2018년 베스트 가요 콜렉션                                     선물
# 3         2018년 베스트 가요 콜렉션  모든 날, 모든 순간 (Every day, Every Moment)
# 4         2018년 베스트 가요 콜렉션                   뚜두뚜두 (DDU-DU DDU-DU)
# 5         2018년 베스트 가요 콜렉션                                     뿜뿜
# 6         2018년 베스트 가요 콜렉션                                    You
# 7         2018년 베스트 가요 콜렉션                              그때 헤어지면 돼
# 8         2018년 베스트 가요 콜렉션                         Roller Coaster
# 9         2018년 베스트 가요 콜렉션                              instagram
# 10        2018년 베스트 가요 콜렉션                                   지나오다
# 11        2018년 베스트 가요 콜렉션                          Way Back Home
# 12        2018년 베스트 가요 콜렉션                                     여행
# 13        2018년 베스트 가요 콜렉션                                    미안해
# 14        2018년 베스트 가요 콜렉션                                Bad Boy
# 15        2018년 베스트 가요 콜렉션                                    주지마
# 16        2018년 베스트 가요 콜렉션                               별이 빛나는 밤
# 17        2018년 베스트 가요 콜렉션                                    밤편지
# 18        2018년 베스트 가요 콜렉션                           Heart Shaker
# 19        2018년 베스트 가요 콜렉션                                    꽃 길
# 20        2018년 베스트 가요 콜렉션                          What is Love?
# 21        2018년 베스트 가요 콜렉션                   Dance The Night Away
# 22        2018년 베스트 가요 콜렉션            밤 (Time for the moon night)
# 23        2018년 베스트 가요 콜렉션                                      비
# 24        2018년 베스트 가요 콜렉션                                기억의 빈자리
# 25        2018년 베스트 가요 콜렉션                          Forever Young
# 26        2018년 베스트 가요 콜렉션                                    눈사람
# 27        2018년 베스트 가요 콜렉션                       소나기 (Feat. 10cm)
# 28        2018년 베스트 가요 콜렉션                                    DNA
# 29        2018년 베스트 가요 콜렉션                                 밤이 되니까
# ...                    ...                                    ...
# 5116  1940's 이전 베스트 가요 콜렉션                               불효자는 웁니다
# 5117  1940's 이전 베스트 가요 콜렉션                         울며 헤진 부산항(釜山港)
# 5118  1940's 이전 베스트 가요 콜렉션                             화류춘몽(花柳春夢)
# 5119  1940's 이전 베스트 가요 콜렉션                                     고향
# 5120  1940's 이전 베스트 가요 콜렉션                           가거라 초립동(草笠童)
# 5121  1940's 이전 베스트 가요 콜렉션                           꿈꾸는 백마강(白馬江)
# 5122  1940's 이전 베스트 가요 콜렉션                                 대지의 항구
# 5123  1940's 이전 베스트 가요 콜렉션                                     선창
# 5124  1940's 이전 베스트 가요 콜렉션                                  아리랑낭랑
# 5125  1940's 이전 베스트 가요 콜렉션                                아주까리 등불
# 5126  1940's 이전 베스트 가요 콜렉션                                 진달래 시첩
# 5127  1940's 이전 베스트 가요 콜렉션                           해저문 황포강(黃浦江)
# 5128  1940's 이전 베스트 가요 콜렉션                                    꽃마차
# 5129  1940's 이전 베스트 가요 콜렉션                                   낙화유수
# 5130  1940's 이전 베스트 가요 콜렉션                        목단강(牧丹江) 편지(片紙)
# 5131  1940's 이전 베스트 가요 콜렉션                                 소주 뱃사공
# 5132  1940's 이전 베스트 가요 콜렉션                                    찔레꽃
# 5133  1940's 이전 베스트 가요 콜렉션                                 꿈속의 사랑
# 5134  1940's 이전 베스트 가요 콜렉션                                    귀국선
# 5135  1940's 이전 베스트 가요 콜렉션                                    고향초
# 5136  1940's 이전 베스트 가요 콜렉션                                가거라 삼팔선
# 5137  1940's 이전 베스트 가요 콜렉션                                울어라 은방울
# 5138  1940's 이전 베스트 가요 콜렉션                                 빈대떡 신사
# 5139  1940's 이전 베스트 가요 콜렉션                                   고향만리
# 5140  1940's 이전 베스트 가요 콜렉션                              비 내리는 고모령
# 5141  1940's 이전 베스트 가요 콜렉션                                 낭랑 18세
# 5142  1940's 이전 베스트 가요 콜렉션                            달도 하나 해도 하나
# 5143  1940's 이전 베스트 가요 콜렉션                                   럭키서울
# 5144  1940's 이전 베스트 가요 콜렉션                                제물포 아가씨
# 5145  1940's 이전 베스트 가요 콜렉션                                 청춘 부르스
#
#                          singer             genre runtime     type  \
# 0                          iKON              랩/힙합   03:29  그룹 (남성)
# 1                           장덕철          발라드/댄스/팝   03:52  그룹 (남성)
# 2               멜로망스(MeloMance)      인디, 발라드/댄스/팝   04:20  듀오 (남성)
# 3     폴킴(Paul Kim) CONNECT 아티스트     발라드/댄스/팝, OST   03:30  솔로 (남성)
# 4                     BLACKPINK          발라드/댄스/팝   03:29  그룹 (여성)
# 5                모모랜드(MOMOLAND)          발라드/댄스/팝   03:28  그룹 (여성)
# 6               멜로망스(MeloMance)            알앤비/소울   04:32  듀오 (남성)
# 7                           로이킴          발라드/댄스/팝   04:08  솔로 (남성)
# 8                            청하          발라드/댄스/팝   03:32  솔로 (여성)
# 9                       DEAN(딘)            알앤비/소울   04:15  솔로 (남성)
# 10                    닐로(Nil_O)          발라드/댄스/팝   04:41  솔로 (남성)
# 11                     숀(SHAUN)         인디, 일렉트로닉   03:34  솔로 (남성)
# 12                       볼빨간사춘기      인디, 발라드/댄스/팝   03:41  듀오 (여성)
# 13                          양다일  발라드/댄스/팝, 알앤비/소울   03:48  솔로 (남성)
# 14            Red Velvet (레드벨벳)          발라드/댄스/팝   03:30  그룹 (여성)
# 15              로꼬 , 화사(Hwa Sa)          발라드/댄스/팝   03:51  솔로 (남성)
# 16                 마마무(Mamamoo)  발라드/댄스/팝, 알앤비/소울   03:31  그룹 (여성)
# 5143  서울의 거리는 명랑한 거리\n명랑한 거리에는 희망이 솟네\n타이프 소리로 해가 저무...
# 5144  갈매기 나래 끝에 진달래빛 노래 적어\n테프가 아롱지는 물굽이에 흘리며\n떠나는 사...
# 5145  아 임이시어 아 임이시어\n어디로 가셨나요 어디로 가셨나요\n나일락 꽃잎이 창 밖에...
#
# [5146 rows x 7 columns]

# %%
bugs_df.to_csv('Bugs.csv', index=False)

# %%
bugs = pd.read_csv('Bugs.csv')
bugs[1000:1010]
# Out:
#                   year                  title                    singer  \
# 1000  2008년 베스트 가요 콜렉션           주문 - MIROTIC              동방신기 (TVXQ!)
# 1001  2008년 베스트 가요 콜렉션            10점 만점에 10점                       2PM
# 1002  2008년 베스트 가요 콜렉션       1분 1초 (feat. 타루)          에픽하이 (EPIK HIGH)
# 1003  2008년 베스트 가요 콜렉션              Baby Baby  소녀시대 (GIRLS' GENERATION)
# 1004  2008년 베스트 가요 콜렉션                Bad Boy                       손담비
# 1005  2008년 베스트 가요 콜렉션         Beautiful Life                    V.O.S.
# 1006  2008년 베스트 가요 콜렉션  D.I.S.C.O (feat. TOP)                       엄정화
# 1007  2008년 베스트 가요 콜렉션              Dangerous                       은지원
# 1008  2008년 베스트 가요 콜렉션            Hey Mr. Big                       이효리
# 1009  2008년 베스트 가요 콜렉션               Hot Girl                 씨야(SeeYa)
#
#                  genre runtime     type  \
# 1000          발라드/댄스/팝   03:28  그룹 (남성)
# 1001          발라드/댄스/팝   03:22  그룹 (남성)
# 1002              랩/힙합   04:28  그룹 (남성)
# 1003          발라드/댄스/팝   03:11  그룹 (여성)
# 1004   일렉트로닉, 발라드/댄스/팝   03:23  솔로 (여성)
# 1005  발라드/댄스/팝, 알앤비/소울   03:25  그룹 (남성)
# 1006   일렉트로닉, 발라드/댄스/팝   03:25  솔로 (여성)
# 1007              랩/힙합   03:29  솔로 (남성)
# 1008          발라드/댄스/팝   03:11  솔로 (여성)
# 1009          발라드/댄스/팝   03:15  그룹 (여성)
#
#                                                   lyric
# 1000  시작은 달콤하게, 평범하게 나에게 끌려 \r\n언제나 그랬듯이 먼저 말을 걸어와 \...
# 1001  That girl 너무 예뻐 Oh my god 기가 막혀 \r\n이건 본 적이 없는...
# 1002  I can't let go (go go go)\r\n어딜봐도 니 모습이 보이고 무너...
# 1003  떨리는 맘 고마운 맘\r\n가득히 담아서\r\n젤 예쁜 포장 속에\r\n전하고 싶은...
# 1004  처음엔 모든 걸 다 해주더니 \r\n내 마음을 흔들어 놓고 \r\n조금씩 나에게 더...
# 1005  변해버린 내 모습에 놀라 \r\n잘라버린 긴 머리 끝이\r\n이렇게도 꽤나 내가 괜...
# 1006  *\r\nD.I.S.C.O 미친 듯이 춤추고 \r\n네 멋대로 Do the disc...
# 1007  언제나 또 넌 내게 많은 것을 원해\r\n내가 할수 있는건 다 했는데\r\nI wa...
# 1008  Hey listen Mr. boy \r\n잘난 척 하는 입술로\r\n이제는 속 깊은...
# 1009  @\r\nJust one more time \r\nJust one more time...
