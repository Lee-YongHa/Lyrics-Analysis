# %%
import pandas as pd

# %%
bugs = pd.read_csv("Bugs_preprocessing.csv")

# %%
bugs.fillna(" ", inplace=True)

# %%
bugs_2018 = pd.DataFrame(bugs[bugs.year==2018]).reset_index(drop=True)
bugs_2017 = pd.DataFrame(bugs[bugs.year==2017]).reset_index(drop=True)
bugs_2016 = pd.DataFrame(bugs[bugs.year==2016]).reset_index(drop=True)
bugs_2015 = pd.DataFrame(bugs[bugs.year==2015]).reset_index(drop=True)
bugs_2014 = pd.DataFrame(bugs[bugs.year==2014]).reset_index(drop=True)
bugs_2013 = pd.DataFrame(bugs[bugs.year==2013]).reset_index(drop=True)
bugs_2012 = pd.DataFrame(bugs[bugs.year==2012]).reset_index(drop=True)
bugs_2011 = pd.DataFrame(bugs[bugs.year==2011]).reset_index(drop=True)
bugs_2010 = pd.DataFrame(bugs[bugs.year==2010]).reset_index(drop=True)
bugs_2009 = pd.DataFrame(bugs[bugs.year==2009]).reset_index(drop=True)
bugs_2008 = pd.DataFrame(bugs[bugs.year==2008]).reset_index(drop=True)
bugs_2007 = pd.DataFrame(bugs[bugs.year==2007]).reset_index(drop=True)
bugs_2006 = pd.DataFrame(bugs[bugs.year==2006]).reset_index(drop=True)
bugs_2005 = pd.DataFrame(bugs[bugs.year==2005]).reset_index(drop=True)
bugs_2004 = pd.DataFrame(bugs[bugs.year==2004]).reset_index(drop=True)
bugs_2003 = pd.DataFrame(bugs[bugs.year==2003]).reset_index(drop=True)
bugs_2002 = pd.DataFrame(bugs[bugs.year==2002]).reset_index(drop=True)
bugs_2001 = pd.DataFrame(bugs[bugs.year==2001]).reset_index(drop=True)
bugs_2000 = pd.DataFrame(bugs[bugs.year==2000]).reset_index(drop=True)
bugs_1999 = pd.DataFrame(bugs[bugs.year==1999]).reset_index(drop=True)
bugs_1998 = pd.DataFrame(bugs[bugs.year==1998]).reset_index(drop=True)
bugs_1997 = pd.DataFrame(bugs[bugs.year==1997]).reset_index(drop=True)
bugs_1996 = pd.DataFrame(bugs[bugs.year==1996]).reset_index(drop=True)
bugs_1995 = pd.DataFrame(bugs[bugs.year==1995]).reset_index(drop=True)
bugs_1994 = pd.DataFrame(bugs[bugs.year==1994]).reset_index(drop=True)
bugs_1993 = pd.DataFrame(bugs[bugs.year==1993]).reset_index(drop=True)
bugs_1992 = pd.DataFrame(bugs[bugs.year==1992]).reset_index(drop=True)
bugs_1991 = pd.DataFrame(bugs[bugs.year==1991]).reset_index(drop=True)
bugs_1990 = pd.DataFrame(bugs[bugs.year==1990]).reset_index(drop=True)
bugs_1989 = pd.DataFrame(bugs[bugs.year==1989]).reset_index(drop=True)
bugs_1988 = pd.DataFrame(bugs[bugs.year==1988]).reset_index(drop=True)
bugs_1987 = pd.DataFrame(bugs[bugs.year==1987]).reset_index(drop=True)
bugs_1986 = pd.DataFrame(bugs[bugs.year==1986]).reset_index(drop=True)
bugs_1985 = pd.DataFrame(bugs[bugs.year==1985]).reset_index(drop=True)
bugs_1984 = pd.DataFrame(bugs[bugs.year==1984]).reset_index(drop=True)
bugs_1983 = pd.DataFrame(bugs[bugs.year==1983]).reset_index(drop=True)
bugs_1982 = pd.DataFrame(bugs[bugs.year==1982]).reset_index(drop=True)
bugs_1981 = pd.DataFrame(bugs[bugs.year==1981]).reset_index(drop=True)
bugs_1980 = pd.DataFrame(bugs[bugs.year==1980]).reset_index(drop=True)
bugs_1979 = pd.DataFrame(bugs[bugs.year==1979]).reset_index(drop=True)
bugs_1978 = pd.DataFrame(bugs[bugs.year==1978]).reset_index(drop=True)
bugs_1977 = pd.DataFrame(bugs[bugs.year==1977]).reset_index(drop=True)
bugs_1976 = pd.DataFrame(bugs[bugs.year==1976]).reset_index(drop=True)
bugs_1975 = pd.DataFrame(bugs[bugs.year==1975]).reset_index(drop=True)
bugs_1974 = pd.DataFrame(bugs[bugs.year==1974]).reset_index(drop=True)
bugs_1973 = pd.DataFrame(bugs[bugs.year==1973]).reset_index(drop=True)
bugs_1972 = pd.DataFrame(bugs[bugs.year==1972]).reset_index(drop=True)
bugs_1971 = pd.DataFrame(bugs[bugs.year==1971]).reset_index(drop=True)
bugs_1970 = pd.DataFrame(bugs[bugs.year==1970]).reset_index(drop=True)
bugs_1969 = pd.DataFrame(bugs[bugs.year==1969]).reset_index(drop=True)
bugs_1968 = pd.DataFrame(bugs[bugs.year==1968]).reset_index(drop=True)
bugs_1967 = pd.DataFrame(bugs[bugs.year==1967]).reset_index(drop=True)
bugs_1966 = pd.DataFrame(bugs[bugs.year==1966]).reset_index(drop=True)
bugs_1965 = pd.DataFrame(bugs[bugs.year==1965]).reset_index(drop=True)
bugs_1964 = pd.DataFrame(bugs[bugs.year==1964]).reset_index(drop=True)

# %%
bugs_year_list = [bugs_2018,bugs_2017,bugs_2016,bugs_2015,bugs_2014,bugs_2013,bugs_2012,bugs_2011,bugs_2010,
                 bugs_2009,bugs_2008,bugs_2007,bugs_2006,bugs_2005,bugs_2004,bugs_2003,bugs_2002,bugs_2001,bugs_2000,
                 bugs_1999,bugs_1998,bugs_1997,bugs_1996,bugs_1995,bugs_1994,bugs_1993,bugs_1992,bugs_1991,bugs_1990,
                 bugs_1989,bugs_1988,bugs_1987,bugs_1986,bugs_1985,bugs_1984,bugs_1983,bugs_1982,bugs_1981,bugs_1980,
                 bugs_1979,bugs_1978,bugs_1977,bugs_1976,bugs_1975,bugs_1974,bugs_1973,bugs_1972,bugs_1971,bugs_1970,
                 bugs_1969,bugs_1968,bugs_1967,bugs_1966,bugs_1965,bugs_1964]

# %%
for i in bugs_year_list:
    for j in range(0, len(i)):
        i["lyrics"][0] += " " + i["lyrics"][j]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
for i in bugs_year_list: 
    f = open(str(i["year"][0]) + ".txt", 'w', encoding='UTF8')
    f.write(i["lyrics"][0])
    f.close()
